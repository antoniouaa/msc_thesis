# %%
import pandas as pd

df = pd.read_csv("nbbo.csv")

# %%
df
# Out:
#             date symbol  exchange      company_name  stock_price_close  \
# 0     01/15/2019   SX5E       NaN  DJ Euro STOXX 50            3068.05
# 1     01/15/2019   SX5E       NaN  DJ Euro STOXX 50            3068.05
# 2     01/15/2019   SX5E       NaN  DJ Euro STOXX 50            3068.05
# 3     01/15/2019   SX5E       NaN  DJ Euro STOXX 50            3068.05
# 4     01/15/2019   SX5E       NaN  DJ Euro STOXX 50            3068.05
# ...          ...    ...       ...               ...                ...
# 3125  01/15/2019   SX5E       NaN  DJ Euro STOXX 50            3068.05
# 3126  01/15/2019   SX5E       NaN  DJ Euro STOXX 50            3068.05
# 3127  01/15/2019   SX5E       NaN  DJ Euro STOXX 50            3068.05
# 3128  01/15/2019   SX5E       NaN  DJ Euro STOXX 50            3068.05
# 3129  01/15/2019   SX5E       NaN  DJ Euro STOXX 50            3068.05
#
#      option_symbol option_expiration  strike call_put style       bid  \
# ...

# %%
calls, puts = df.iloc[::2], df.iloc[1::2]

# %%
calls.reset_index()
puts.reset_index()

df.describe()
# Out:
#        exchange  stock_price_close        strike          bid          ask  \
# count       0.0            3130.00   3130.000000  3130.000000  3130.000000
# mean        NaN            3068.05   3475.830671   307.682794   313.288687
# std         NaN               0.00   1949.995521   868.159349   871.897865
# min         NaN            3068.05    250.000000     0.001000     0.001000
# 25%         NaN            3068.05   2275.000000     0.001000     0.001000
# 50%         NaN            3068.05   3100.000000     1.500000     2.250000
# 75%         NaN            3068.05   4000.000000   236.725000   243.950000
# max         NaN            3068.05  10000.000000  7080.700000  7091.000000
#
#         mean_price   settlement        volume  open_interest  \
# count  3130.000000  3130.000000   3130.000000    3130.000000
# mean    310.383130   705.880096    338.693291   10738.887540
# std     870.018521  1227.755983   2369.845198   27627.500729
# ...
