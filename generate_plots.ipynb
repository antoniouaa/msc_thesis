# %%
import numpy as np
import matplotlib.pyplot as plt 
import math

def sigmoid(x):
    a = []
    for item in x:
        a.append(1/(1+math.exp(-item)))
    return a

x = np.arange(-10., 10., 0.2)
y = sigmoid(x)

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.spines['left'].set_position('center')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
ax.yaxis.set_ticks([0, 0.5, 1.0])

ax.plot(x,y)
ax.grid()
fig.show()
fig.savefig("tex\\figures\\sigmoid.png")

# %%
x = np.linspace(-10, 10)
y = x.copy()
y[y<0] = 0
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.spines['left'].set_position('center')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
plt.plot(x, y)
ax.grid()
fig.show()
fig.savefig("tex\\figures\\relu.png")

# %%
x = np.linspace(-10, 10)

def tanh(x):
    return (math.exp(2*x)-1) / (math.exp(2*x) + 1)

y = np.vectorize(tanh)(x)

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.spines['left'].set_position('center')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
ax.yaxis.set_ticks([-1.0, -0.5, 0, 0.5, 1.0])

plt.plot(x, y)
ax.grid()
fig.show()
fig.savefig("tex\\figures\\tanh.png")

# %%
import numpy as np
import matplotlib.pyplot as plt 

x = np.linspace(-2, 2, num=101, endpoint=True)
y = abs(x)
y_ = x**2

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.spines['left'].set_position('center')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
ax.yaxis.set_ticks(np.linspace(-4, 4, num=17))
ax.xaxis.set_ticks([-2, -1.5, -1, -0.5, 0, 0.5, 1, 1.5, 2])

plt.plot(x, y)
plt.plot(x, y_)
ax.grid()
fig.show()
fig.savefig("tex\\figures\\maevsmse.png")
